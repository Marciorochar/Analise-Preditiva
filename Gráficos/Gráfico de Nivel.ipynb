# %% [markdown]
# <a href="https://colab.research.google.com/github/Marciorochar/Analise-Preditiva/blob/main/Gr%C3%A1ficos/Gr%C3%A1fico%20de%20Nivel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #📊 Componete de Nível de uma Série Temporal
# - Nível:
#
# Valor onde a demanda orbita (média)
#
# Captura a escala da série temporal
#
# Se não existir outros padrões, a previsão será um valor constante.

# %%
# Instalar bibliotecas
# !pip install pandas matplotlib openpyxl

# Imports
import pandas as pd
import matplotlib.pyplot as plt

# Upload do arquivo Excel
from google.colab import files
uploaded = files.upload()

# Leitura do arquivo Excel
nome_arquivo = list(uploaded.keys())[0]
df = pd.read_excel(nome_arquivo, engine='openpyxl')

# Converter colunas
df['Timestamp'] = pd.to_datetime(df['Timestamp'], dayfirst=True, errors='coerce')
df['Camisetas_básicas_masculinas'] = pd.to_numeric(df['Camisetas_básicas_masculinas'], errors='coerce')
df = df.dropna(subset=['Timestamp', 'Camisetas_básicas_masculinas'])

# Ordenar por data
df = df.sort_values('Timestamp')

# Calcular o nível médio
nivel_medio = df['Camisetas_básicas_masculinas'].mean()

# Gráfico
plt.figure(figsize=(12, 6))
plt.plot(df['Timestamp'], df['Camisetas_básicas_masculinas'], label='Vendas Diárias', color='steelblue')
plt.axhline(y=nivel_medio, color='red', linestyle='--', linewidth=2, label=f'Nível Médio: {nivel_medio:.2f}')

plt.title('Gráfico de Nível - Camisetas Básicas Masculinas')
plt.xlabel('Data')
plt.ylabel('Quantidade de Vendas')
plt.legend()
plt.grid(True, linestyle='--', alpha=0.5)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# ...
#      <input type="file" id="files-d4a82e0e-73b9-4068-8bb8-9af0086dfa6a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d4a82e0e-73b9-4068-8bb8-9af0086dfa6a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
